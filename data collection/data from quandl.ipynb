# %%
pip install quandl
# Out:
# ...
#   Created wheel for inflection: filename=inflection-0.3.1-py3-none-any.whl size=6080 sha256=15b80611d808a01929e295b7569d87d68091e2494533b5d2351ff8110f2f8b52
#   Stored in directory: c:\users\jdcoh\appdata\local\pip\cache\wheels\13\61\89\9192774c0f1e6c3342354df9f4804d7a9de80ac88e062d2e56
# Successfully built inflection
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import quandl

# %%
aapl = quandl.get('WIKI/AAPL', start_date= '2014-01-01', end_date = '2015-01-01'
                 )

# %%
aapl.describe()
# Out:
#              Open        High         Low       Close        Volume  \
# count  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   295.142565  297.560943  293.003747  295.402249  3.465878e+07
# std    224.587200  226.358172  223.146605  224.921476  2.619673e+07
# min     90.210000   90.700000   89.650000   90.280000  5.704900e+06
# 25%     99.390000  100.672500   98.527500   99.620000  1.083302e+07
# 50%    113.365000  114.410000  112.010000  113.425000  3.375798e+07
# 75%    534.857500  539.094925  530.712500  535.777500  5.168910e+07
# max    649.900000  651.260000  644.470000  647.350000  1.895606e+08
#
#        Ex-Dividend  Split Ratio   Adj. Open   Adj. High    Adj. Low  \
# count   252.000000   252.000000  252.000000  252.000000  252.000000
# mean      0.028889     1.023810   86.890605   87.638061   86.197405
# std       0.284795     0.377964   13.118453   13.288783   12.949168
# min       0.000000     1.000000   65.820564   66.664622   65.603901
# ...
