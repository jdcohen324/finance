# %%
import pandas as pd
import pandas_datareader as pdr
import datetime

# %%
# Out:
# C:\Users\jdcoh\anaconda3\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
aapl=pdr.get_data_yahoo('AAPL', start=datetime.datetime(2015,1,1), end=datetime.datetime(2020,1,1))

# %%
aapl.describe()
# Out:
#               High          Low         Open        Close        Volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    155.756200   153.075008   154.397377   154.476566  3.589995e+07
# std      44.413001    43.702152    44.009480    44.119589  1.788448e+07
# min      91.669998    89.470001    90.000000    90.339996  1.136200e+07
# 25%     116.522497   114.510000   115.800003   115.504999  2.378072e+07
# 50%     152.050003   149.175003   150.375000   150.555000  3.157625e+07
# 75%     187.382496   184.669998   186.002506   186.002502  4.286455e+07
# max     293.970001   289.519989   291.119995   293.649994  1.622063e+08
#
#          Adj Close
# count  1258.000000
# mean    149.094641
# std      45.932973
# min      85.192909
# 25%     108.082399
# 50%     145.557358
# 75%     182.013893
# max     292.954712

# %%
aapl.to_csv('aapl_try_example.csv')
download_aapl = 'aapl_try_example.csv'

# %%
import matplotlib as plt
aapl['Volume'].plot(grid=True)
google['Volume'].plot(grid=True)

# %%
aapl['Open'].plot(grid=True)
google=pdr.get_data_yahoo('GOOGL', start=datetime.datetime(2015,1,1), end=datetime.datetime(2020,1,1))
google['Open'].plot(grid=True)
aapl_matched_to_google = 5 * aapl['Open']  
aapl_matched_to_google.plot(grid=True)

# %%
difference = google['Open'] - aapl_matched_to_google
difference.plot(grid=True)

# %%
volatility_google = (google['Open']-google['Close'])/google['Open']

volatility_google.plot(grid=True)

# %%
google['Volume'].plot(grid=True)

# %%
google=pdr.get_data_yahoo('GOOGL', start=datetime.datetime(2008,1,1), end=datetime.datetime(2012,1,1))
google['Open'].plot(grid=True)

# %%
def get(tickers, startdate, enddate):
    def data(ticker):
        return(pdr.get_data_yahoo(ticker, start = startdate, end = enddate))
    datas = map(data, tickers)
    return(pd.concat(datas,keys=tickers,names=['Ticker','Date']))

# %%
tickers = ['MSFT', 'MMM']
all_data = get(tickers, datetime.datetime(2015,1,1), datetime.datetime(2019,1,1))

# %%
print (all_data)
# Out:
#                          High         Low        Open       Close      Volume  \
# Ticker Date
# MSFT   2015-01-02   47.419998   46.540001   46.660000   46.759998  27913900.0
#        2015-01-05   46.730000   46.250000   46.369999   46.330002  39673900.0
#        2015-01-06   46.750000   45.540001   46.380001   45.650002  36447900.0
#        2015-01-07   46.459999   45.490002   45.980000   46.230000  29114100.0
#        2015-01-08   47.750000   46.720001   46.750000   47.590000  29645200.0
# ...                       ...         ...         ...         ...         ...
# MMM    2018-12-24  183.539993  178.509995  181.889999  178.619995   2249500.0
#        2018-12-26  186.330002  176.869995  179.380005  186.259995   2925500.0
#        2018-12-27  190.699997  182.880005  183.500000  190.699997   2809000.0
#        2018-12-28  192.300003  188.570007  191.809998  189.369995   2311400.0
#        2018-12-31  191.649994  188.500000  190.339996  190.539993   1804400.0
#
# ...
